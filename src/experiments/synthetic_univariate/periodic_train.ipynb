# %%
# COLAB SETUP

# %cd /content
# !rm -rf /content/proto-tsrl
# !git clone https://github.com/haiyan-wang/proto-tsrl.git /content/proto-tsrl
# %cd /content/proto-tsrl

from google.colab import drive, runtime
drive.mount('/content/drive')

import sys
import os

project_root = os.getcwd()
if project_root not in sys.path:
    sys.path.insert(0, project_root)

print(project_root)
# Out:
# /content
# Cloning into '/content/proto-tsrl'...
# remote: Enumerating objects: 351, done.
# remote: Counting objects: 100% (351/351), done.
# remote: Compressing objects: 100% (280/280), done.
# remote: Total 351 (delta 180), reused 165 (delta 66), pack-reused 0 (from 0)
# Receiving objects: 100% (351/351), 3.75 MiB | 8.61 MiB/s, done.
# Resolving deltas: 100% (180/180), done.
# /content/proto-tsrl
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# /content/proto-tsrl

# %%
import functools

import numpy as np

from sklearn.model_selection import StratifiedShuffleSplit

import torch
from torch.utils.data import Dataset, DataLoader
import torch.nn as nn
import torch.nn.functional as F

from src.experiments.synthetic_univariate.univariate_model import UnivariateModel
from src.utils.sampling_utils import *
from src.utils.training_utils import *
from src.experiments.ppg.ppg_data_utils import *

# %%
### SETTINGS

SEED = 42

# device
DEVICE = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(DEVICE)

# dataloaders
BATCH_SIZE = 128
VAL_RATIO = 0.05
N_WORKERS = 4

# contrastive sampling
COLLATE_FN_KWARGS = {
    'min_len': 300,
    'max_len': 600,
    'num_neg': 10,
    'min_overlap': 0.5,
    'min_var': 5e-3,
    'max_var': 1e-2
}

# schedule
N_EPOCHS_STAGE1 = 30
N_EPOCHS_STAGE2 = 15
N_EPOCHS_STAGE3 = 10
TOTAL_EPOCHS = N_EPOCHS_STAGE1 + N_EPOCHS_STAGE2 + N_EPOCHS_STAGE3

# logging
CHECKPOINT_EPOCHS = [*range(1, TOTAL_EPOCHS + 1)] # 1-indexed
SAVE_DIR = "/content/drive/MyDrive/Duke/Senior Year/Thesis/experiments/periodic_univariate/checkpoints"

# architecture
MASK_PROB = 0.2
MID_WEIGHT = 0.5
PROTO_NEG_MARGIN = 0.1
PROTO_DIVERSITY_THRESHOLD = 0.2
LAMBDA_PROTO = 1.0
TEMPERATURE = 1.0
LAMBDA_REPR = 1e-3
GRADIENT_CLIP = 1.0

# parameter settings and optimizers
REP_DIMS = [300]
MODELS = []
OPTIMIZER_DICTS = []
CKPT_PATHS = []
for dim in REP_DIMS:
    model = UnivariateModel(representation_dimension = dim, mask_probability = MASK_PROB)
    if torch.cuda.device_count() > 1:
        model = nn.DataParallel(model)
    model = model.to(DEVICE)
    MODELS.append(model)

    ckpt_path = f"{SAVE_DIR}/dim{dim}"
    CKPT_PATHS.append(ckpt_path)

    opt_dict = {
    "stage1": torch.optim.Adam(model.parameters(), lr = 1e-3, weight_decay = 1e-5),
    "stage2": torch.optim.Adam(model.parameters(), lr = 1e-3, weight_decay = 1e-5),
    "stage3": torch.optim.Adam(model.parameters(), lr = 1e-4, weight_decay = 1e-5),
    }
    OPTIMIZER_DICTS.append(opt_dict)

SCHEDULER = None
# Out:
# cuda:0

# %%
### LOAD DATA

with np.load("/content/drive/MyDrive/Duke/Senior Year/Thesis/data/periodic_univariate.npz", allow_pickle = True) as data:
    series = list(data["series"])
y = np.loadtxt("/content/drive/MyDrive/Duke/Senior Year/Thesis/data/periodic_univariate_labels.csv", delimiter = ',')

# shuffle
rng = np.random.default_rng(SEED)
idx = rng.permutation(len(series))
series = [series[i] for i in idx]
y = y[idx]

# split
split = int(0.95 * len(series))
train_series = series[:split]
train_labels = y[:split]
test_series = series[split:]
test_labels = y[split:]

ds_train, ds_test = TimeSeriesDataset(train_series), TimeSeriesDataset(test_series)

collate_fn = functools.partial(
    contrastive_collate,
    min_len = COLLATE_FN_KWARGS['min_len'],
    max_len = COLLATE_FN_KWARGS['max_len'],
    num_neg = COLLATE_FN_KWARGS['num_neg'],
    min_overlap = COLLATE_FN_KWARGS['min_overlap'],
    min_var = COLLATE_FN_KWARGS['min_var'],
    max_var = COLLATE_FN_KWARGS['max_var']
)

dl_train = DataLoader(
    ds_train,
    batch_size = BATCH_SIZE,
    shuffle = True,
    collate_fn = collate_fn,
    num_workers = N_WORKERS,
    pin_memory = True,
    drop_last = True
)

dl_test = DataLoader(
    ds_test,
    batch_size = len(test_series),
    shuffle = False,
    num_workers = N_WORKERS,
    pin_memory = True,
)

# %%
### TRAINING

for i, dim in enumerate(REP_DIMS):
    print(f'TRAINING MODEL WITH REPRESENTATION DIMENSION {dim}')
    history = run_training(
        model = MODELS[i],
        train_loader = dl_train,
        val_loader = None,
        device = DEVICE,
        optimizer_dict = OPTIMIZER_DICTS[i],
        epochs_stage1 = N_EPOCHS_STAGE1,
        epochs_stage2 = N_EPOCHS_STAGE2,
        epochs_stage3 = N_EPOCHS_STAGE3,
        scheduler_dict = SCHEDULER,
        mid_weight = MID_WEIGHT,
        proto_neg_margin = PROTO_NEG_MARGIN,
        proto_diversity_threshold = PROTO_DIVERSITY_THRESHOLD,
        lambda_proto = LAMBDA_PROTO,
        temperature = TEMPERATURE,
        lambda_repr = LAMBDA_REPR,
        grad_clip_norm = GRADIENT_CLIP,
        checkpoint_path = CKPT_PATHS[i],
        checkpoint_epochs = CHECKPOINT_EPOCHS,
        collector_fn = None,
        use_amp = True
    )
# Out:
# TRAINING MODEL WITH REPRESENTATION DIMENSION 300
# Training for 55 epochs.
#
# === stage1 (30 epochs) ===
# [stage1] epoch 1/30 | global 1/55
#   train loss: 3.377659
# Saved checkpoint at epoch 1
# [stage1] epoch 2/30 | global 2/55
#   train loss: 1.506121
# Saved checkpoint at epoch 2
# [stage1] epoch 3/30 | global 3/55
#   train loss: 1.261269
# Saved checkpoint at epoch 3
# [stage1] epoch 4/30 | global 4/55
#   train loss: 1.214666
# Saved checkpoint at epoch 4
# [stage1] epoch 5/30 | global 5/55
#   train loss: 1.191215
# Saved checkpoint at epoch 5
# [stage1] epoch 6/30 | global 6/55
#   train loss: 1.155638
# Saved checkpoint at epoch 6
# [stage1] epoch 7/30 | global 7/55
#   train loss: 1.138373
# Saved checkpoint at epoch 7
# [stage1] epoch 8/30 | global 8/55
#   train loss: 1.003990
# Saved checkpoint at epoch 8
# [stage1] epoch 9/30 | global 9/55
#   train loss: 0.943646
# Saved checkpoint at epoch 9
# [stage1] epoch 10/30 | global 10/55
#   train loss: 0.906719
# Saved checkpoint at epoch 10
# [stage1] epoch 11/30 | global 11/55
#   train loss: 0.890386
# Saved checkpoint at epoch 11
# [stage1] epoch 12/30 | global 12/55
#   train loss: 0.884313
# Saved checkpoint at epoch 12
# [stage1] epoch 13/30 | global 13/55
#   train loss: 0.877083
# Saved checkpoint at epoch 13
# [stage1] epoch 14/30 | global 14/55
#   train loss: 0.871314
# Saved checkpoint at epoch 14
# [stage1] epoch 15/30 | global 15/55
#   train loss: 0.867173
# Saved checkpoint at epoch 15
# [stage1] epoch 16/30 | global 16/55
#   train loss: 0.854976
# Saved checkpoint at epoch 16
# [stage1] epoch 17/30 | global 17/55
#   train loss: 0.849787
# Saved checkpoint at epoch 17
# [stage1] epoch 18/30 | global 18/55
#   train loss: 0.842806
# Saved checkpoint at epoch 18
# [stage1] epoch 19/30 | global 19/55
#   train loss: 0.843670
# Saved checkpoint at epoch 19
# [stage1] epoch 20/30 | global 20/55
#   train loss: 0.837139
# Saved checkpoint at epoch 20
# [stage1] epoch 21/30 | global 21/55
#   train loss: 0.826298
# Saved checkpoint at epoch 21
# [stage1] epoch 22/30 | global 22/55
#   train loss: 0.787882
# Saved checkpoint at epoch 22
# [stage1] epoch 23/30 | global 23/55
#   train loss: 0.778072
# Saved checkpoint at epoch 23
# [stage1] epoch 24/30 | global 24/55
#   train loss: 0.772031
# Saved checkpoint at epoch 24
# [stage1] epoch 25/30 | global 25/55
#   train loss: 0.766054
# Saved checkpoint at epoch 25
# [stage1] epoch 26/30 | global 26/55
#   train loss: 0.758118
# Saved checkpoint at epoch 26
# [stage1] epoch 27/30 | global 27/55
#   train loss: 0.751580
# Saved checkpoint at epoch 27
# [stage1] epoch 28/30 | global 28/55
#   train loss: 0.746570
# Saved checkpoint at epoch 28
# [stage1] epoch 29/30 | global 29/55
#   train loss: 0.739460
# Saved checkpoint at epoch 29
# [stage1] epoch 30/30 | global 30/55
#   train loss: 0.735321
# Saved checkpoint at epoch 30
#
# === stage2 (15 epochs) ===
# [stage2] epoch 1/15 | global 31/55
#   train loss: 1.696396
# Saved checkpoint at epoch 31
# [stage2] epoch 2/15 | global 32/55
#   train loss: 1.610070
# Saved checkpoint at epoch 32
# [stage2] epoch 3/15 | global 33/55
#   train loss: 1.608760
# Saved checkpoint at epoch 33
# [stage2] epoch 4/15 | global 34/55
#   train loss: 1.608002
# Saved checkpoint at epoch 34
# [stage2] epoch 5/15 | global 35/55
#   train loss: 1.607948
# Saved checkpoint at epoch 35
# [stage2] epoch 6/15 | global 36/55
#   train loss: 1.607196
# Saved checkpoint at epoch 36
# [stage2] epoch 7/15 | global 37/55
#   train loss: 1.607024
# Saved checkpoint at epoch 37
# [stage2] epoch 8/15 | global 38/55
#   train loss: 1.607440
# Saved checkpoint at epoch 38
# [stage2] epoch 9/15 | global 39/55
#   train loss: 1.606413
# Saved checkpoint at epoch 39
# [stage2] epoch 10/15 | global 40/55
#   train loss: 1.606553
# Saved checkpoint at epoch 40
# [stage2] epoch 11/15 | global 41/55
#   train loss: 1.605846
# Saved checkpoint at epoch 41
# [stage2] epoch 12/15 | global 42/55
#   train loss: 1.606399
# Saved checkpoint at epoch 42
# [stage2] epoch 13/15 | global 43/55
#   train loss: 1.605679
# Saved checkpoint at epoch 43
# [stage2] epoch 14/15 | global 44/55
#   train loss: 1.605484
# Saved checkpoint at epoch 44
# [stage2] epoch 15/15 | global 45/55
#   train loss: 1.606048
# Saved checkpoint at epoch 45
#
# === stage3 (10 epochs) ===
# [stage3] epoch 1/10 | global 46/55
#   train loss: 1.593466
# Saved checkpoint at epoch 46
# [stage3] epoch 2/10 | global 47/55
#   train loss: 1.593112
# Saved checkpoint at epoch 47
# [stage3] epoch 3/10 | global 48/55
#   train loss: 1.592086
# Saved checkpoint at epoch 48
# [stage3] epoch 4/10 | global 49/55
#   train loss: 1.592607
# Saved checkpoint at epoch 49
# [stage3] epoch 5/10 | global 50/55
#   train loss: 1.591753
# Saved checkpoint at epoch 50
# [stage3] epoch 6/10 | global 51/55
#   train loss: 1.592264
# Saved checkpoint at epoch 51
# [stage3] epoch 7/10 | global 52/55
#   train loss: 1.592996
# Saved checkpoint at epoch 52
# [stage3] epoch 8/10 | global 53/55
#   train loss: 1.591715
# Saved checkpoint at epoch 53
# [stage3] epoch 9/10 | global 54/55
#   train loss: 1.591757
# Saved checkpoint at epoch 54
# [stage3] epoch 10/10 | global 55/55
#   train loss: 1.591692
# Saved checkpoint at epoch 55

# %%
runtime.unassign()
